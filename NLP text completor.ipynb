# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# import libraries needed, read the dataset
import nltk, re, pprint, string
nltk.download('punkt')
from nltk import word_tokenize, sent_tokenize
string.punctuation = string.punctuation +'“'+'”'+'-'+'’'+'‘'+'—'
string.punctuation = string.punctuation.replace('.', '')
file = open('/content/drive/MyDrive/Dataset/corpus.txt', encoding = 'utf8').read()
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.

# %%
#preprocess data
file_nl_removed = ""
for line in file:
  line_nl_removed = line.replace("\n", " ")      #removes newlines
  file_nl_removed += line_nl_removed
file_p = "".join([char for char in file_nl_removed if char not in string.punctuation])   #removes all special characters

# %%
sents = nltk.sent_tokenize(file_p)
print("The number of sentences is", len(sents)) 
#prints the number of sentences
words = nltk.word_tokenize(file_p)
print("The number of tokens is", len(words)) 
#prints the number of tokens
average_tokens = round(len(words)/len(sents))
print("The average number of tokens per sentence is",
average_tokens) 
#prints the average number of tokens per sentence
unique_tokens = set(words)
print("The number of unique tokens are", len(unique_tokens)) 
#prints the number of unique tokens
# Out:
# The number of sentences is 95
# The number of tokens is 1427
# The average number of tokens per sentence is 15
# The number of unique tokens are 459

# %%
from nltk.util import ngrams
nltk.download('stopwords')
from nltk.corpus import stopwords
stop_words = set(stopwords.words('english'))
unigram=[]
bigram=[]
trigram=[]
fourgram=[]
tokenized_text = []
for sentence in sents:
    sentence = sentence.lower()
    sequence = word_tokenize(sentence) 
    for word in sequence:
        if (word =='.'):
            sequence.remove(word) 
        else:
            unigram.append(word)
    tokenized_text.append(sequence) 
    bigram.extend(list(ngrams(sequence, 2)))  
#unigram, bigram, trigram, and fourgram models are created
    trigram.extend(list(ngrams(sequence, 3)))
   # fourgram.extend(list(ngrams(sequence, 4)))
def removal(x):     
#removes ngrams containing only stopwords
    y = []
    for pair in x:
        count = 0
        for word in pair:
            if word in stop_words:
                count = count or 0
            else:
                count = count or 1
        if (count==1):
            y.append(pair)
    return(y)
bigram = removal(bigram)
trigram = removal(trigram)             
fourgram = removal(fourgram)
freq_bi = nltk.FreqDist(bigram)
freq_tri = nltk.FreqDist(trigram)
freq_four = nltk.FreqDist(fourgram)
print("Most common n-grams without stopword removal and without add-1 smoothing: \n")
print ("Most common bigrams: ", freq_bi.most_common(50))
print ("\nMost common trigrams: ", freq_tri.most_common(100))
#print ("\nMost common fourgrams: ", freq_four.most_common(5))
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# Most common n-grams without stopword removal and without add-1 smoothing:
#
# Most common bigrams:  [(('old', 'man'), 23), (('the', 'old'), 22), (('the', 'boy'), 15), (('man', 'said'), 10), (('boy', 'said'), 8), (('gaff', 'and'), 3), (('the', 'sail'), 3), (('the', 'mast'), 3), (('i', 'know'), 3), (('the', 'terrace'), 3), (('take', 'the'), 3), (('the', 'wind'), 3), (('i', 'would'), 3), (('like', 'to'), 3), (('the', 'box'), 3), (('far', 'out'), 3), (('had', 'gone'), 2), (('a', 'fish'), 2), (('the', 'first'), 2), (('forty', 'days'), 2), (('a', 'boy'), 2), (('boy', 'had'), 2), (('days', 'without'), 2), (('fish', 'the'), 2), (('man', 'was'), 2), (('come', 'in'), 2), (('day', 'with'), 2), (('the', 'coiled'), 2), (('coiled', 'lines'), 2), (('the', 'gaff'), 2), (('his', 'eyes'), 2), (('santiago', 'the'), 2), (('the', 'skiff'), 2), (('fish', 'and'), 2), (('a', 'lucky'), 2), (('lucky', 'boat'), 2), (('you', 'went'), 2), (('i', 'remember'), 2), (('remember', 'the'), 2), (('yes', 'the'), 2), (('a', 'beer'), 2), (('terrace', 'and'), 2), (('the', 'stuff'), 2), (('stuff', 'home'), 2), (('looked', 'at'), 2), (('the', 'fish'), 2), (('the', 'shark'), 2), (('shark', 'factory'), 2), (('to', 'get'), 2), (('would', 'like'), 2)]
#
# Most common trigrams:  [(('the', 'old', 'man'), 21), (('old', 'man', 'said'), 10), (('the', 'boy', 'said'), 8), (('and', 'the', 'boy'), 4), (('on', 'the', 'terrace'), 3), (('old', 'man', 'was'), 2), (('the', 'gaff', 'and'), 2), (('santiago', 'the', 'boy'), 2), (('no', 'the', 'old'), 2), (('a', 'lucky', 'boat'), 2), (('the', 'terrace', 'and'), 2), (('take', 'the', 'stuff'), 2), (('the', 'stuff', 'home'), 2), (('looked', 'at', 'him'), 2), (('the', 'shark', 'factory'), 2), (('when', 'the', 'wind'), 2), (('i', 'would', 'like'), 2), (('would', 'like', 'to'), 2), (('in', 'a', 'boat'), 2), (('i', 'can', 'remember'), 2), (('and', 'the', 'noise'), 2), (('the', 'noise', 'of'), 2), (('i', 'can', 'get'), 2), (('he', 'had', 'attained'), 2), (('get', 'him', 'to'), 2), (('would', 'steal', 'from'), 2), (('was', 'an', 'old'), 1), (('an', 'old', 'man'), 1), (('old', 'man', 'who'), 1), (('man', 'who', 'fished'), 1), (('who', 'fished', 'alone'), 1), (('fished', 'alone', 'in'), 1), (('alone', 'in', 'a'), 1), (('in', 'a', 'skiff'), 1), (('a', 'skiff', 'in'), 1), (('skiff', 'in', 'the'), 1), (('in', 'the', 'gulf'), 1), (('the', 'gulf', 'stream'), 1), (('gulf', 'stream', 'and'), 1), (('stream', 'and', 'he'), 1), (('he', 'had', 'gone'), 1), (('had', 'gone', 'eightyfour'), 1), (('gone', 'eightyfour', 'days'), 1), (('eightyfour', 'days', 'now'), 1), (('days', 'now', 'without'), 1), (('now', 'without', 'taking'), 1), (('without', 'taking', 'a'), 1), (('taking', 'a', 'fish'), 1), (('in', 'the', 'first'), 1), (('the', 'first', 'forty'), 1), (('first', 'forty', 'days'), 1), (('forty', 'days', 'a'), 1), (('days', 'a', 'boy'), 1), (('a', 'boy', 'had'), 1), (('boy', 'had', 'been'), 1), (('but', 'after', 'forty'), 1), (('after', 'forty', 'days'), 1), (('forty', 'days', 'without'), 1), (('days', 'without', 'a'), 1), (('without', 'a', 'fish'), 1), (('a', 'fish', 'the'), 1), (('fish', 'the', 'boys'), 1), (('the', 'boys', 'parents'), 1), (('boys', 'parents', 'had'), 1), (('parents', 'had', 'told'), 1), (('had', 'told', 'him'), 1), (('told', 'him', 'that'), 1), (('that', 'the', 'old'), 1), (('man', 'was', 'now'), 1), (('was', 'now', 'definitely'), 1), (('now', 'definitely', 'and'), 1), (('definitely', 'and', 'finally'), 1), (('and', 'finally', 'salao'), 1), (('finally', 'salao', 'which'), 1), (('salao', 'which', 'is'), 1), (('is', 'the', 'worst'), 1), (('the', 'worst', 'form'), 1), (('worst', 'form', 'of'), 1), (('form', 'of', 'unlucky'), 1), (('of', 'unlucky', 'and'), 1), (('unlucky', 'and', 'the'), 1), (('the', 'boy', 'had'), 1), (('boy', 'had', 'gone'), 1), (('had', 'gone', 'at'), 1), (('gone', 'at', 'their'), 1), (('at', 'their', 'orders'), 1), (('their', 'orders', 'in'), 1), (('orders', 'in', 'another'), 1), (('in', 'another', 'boat'), 1), (('another', 'boat', 'which'), 1), (('boat', 'which', 'caught'), 1), (('which', 'caught', 'three'), 1), (('caught', 'three', 'good'), 1), (('three', 'good', 'fish'), 1), (('good', 'fish', 'the'), 1), (('fish', 'the', 'first'), 1), (('the', 'first', 'week'), 1), (('it', 'made', 'the'), 1), (('made', 'the', 'boy'), 1), (('the', 'boy', 'sad'), 1)]

# %%
#stopwords = code for downloading stop words through nltk
from nltk.corpus import stopwords
stop_words = set(stopwords.words('english'))
#prints top 10 unigrams, bigrams after removing stopwords
print("Most common n-grams with stopword removal and without add-1 smoothing: \n")
unigram_sw_removed = [p for p in unigram if p not in stop_words]
fdist = nltk.FreqDist(unigram_sw_removed)
print("Most common unigrams: ", fdist.most_common(100))
bigram_sw_removed = []
bigram_sw_removed.extend(list(ngrams(unigram_sw_removed, 2)))
fdist = nltk.FreqDist(bigram_sw_removed)
print("\nMost common bigrams: ", fdist.most_common(100))
# Out:
# Most common n-grams with stopword removal and without add-1 smoothing:
#
# Most common unigrams:  [('old', 27), ('man', 24), ('said', 20), ('boy', 18), ('fish', 11), ('boat', 9), ('remember', 7), ('get', 7), ('went', 6), ('lines', 5), ('like', 5), ('eyes', 5), ('go', 5), ('would', 5), ('skiff', 4), ('days', 4), ('first', 4), ('good', 4), ('made', 4), ('come', 4), ('day', 4), ('sail', 4), ('big', 4), ('take', 4), ('fishermen', 4), ('carried', 4), ('two', 4), ('gone', 3), ('without', 3), ('caught', 3), ('see', 3), ('coiled', 3), ('gaff', 3), ('harpoon', 3), ('mast', 3), ('looked', 3), ('know', 3), ('leave', 3), ('terrace', 3), ('home', 3), ('many', 3), ('wind', 3), ('sardines', 3), ('box', 3), ('steal', 3), ('far', 3), ('forty', 2), ('three', 2), ('sad', 2), ('carry', 2), ('furled', 2), ('brown', 2), ('blotches', 2), ('sea', 2), ('well', 2), ('scars', 2), ('heavy', 2), ('fresh', 2), ('everything', 2), ('santiago', 2), ('lucky', 2), ('ones', 2), ('quite', 2), ('yes', 2), ('beer', 2), ('stuff', 2), ('current', 2), ('already', 2), ('across', 2), ('shark', 2), ('factory', 2), ('cut', 2), ('smell', 2), ('today', 2), ('years', 2), ('tomorrow', 2), ('net', 2), ('bought', 2), ('nearly', 2), ('brought', 2), ('noise', 2), ('clubbing', 2), ('together', 2), ('four', 2), ('baits', 2), ('put', 2), ('let', 2), ('one', 2), ('never', 2), ('attained', 2), ('knew', 2), ('going', 2), ('work', 2), ('something', 2), ('truly', 2), ('bad', 2), ('strange', 2), ('turtleing', 2), ('gear', 2), ('fished', 1)]
#
# Most common bigrams:  [(('old', 'man'), 23), (('man', 'said'), 10), (('boy', 'said'), 8), (('days', 'without'), 3), (('gaff', 'harpoon'), 3), (('fish', 'first'), 2), (('forty', 'days'), 2), (('without', 'fish'), 2), (('coiled', 'lines'), 2), (('lines', 'gaff'), 2), (('santiago', 'boy'), 2), (('lucky', 'boat'), 2), (('take', 'stuff'), 2), (('stuff', 'home'), 2), (('shark', 'factory'), 2), (('get', 'sardines'), 2), (('would', 'like'), 2), (('noise', 'clubbing'), 2), (('together', 'old'), 2), (('get', 'four'), 2), (('work', 'far'), 2), (('far', 'boy'), 2), (('truly', 'big'), 2), (('strange', 'old'), 2), (('went', 'turtleing'), 2), (('big', 'fish'), 2), (('would', 'steal'), 2), (('steal', 'old'), 2), (('man', 'fished'), 1), (('fished', 'alone'), 1), (('alone', 'skiff'), 1), (('skiff', 'gulf'), 1), (('gulf', 'stream'), 1), (('stream', 'gone'), 1), (('gone', 'eightyfour'), 1), (('eightyfour', 'days'), 1), (('without', 'taking'), 1), (('taking', 'fish'), 1), (('first', 'forty'), 1), (('days', 'boy'), 1), (('boy', 'forty'), 1), (('fish', 'boys'), 1), (('boys', 'parents'), 1), (('parents', 'told'), 1), (('told', 'old'), 1), (('man', 'definitely'), 1), (('definitely', 'finally'), 1), (('finally', 'salao'), 1), (('salao', 'worst'), 1), (('worst', 'form'), 1), (('form', 'unlucky'), 1), (('unlucky', 'boy'), 1), (('boy', 'gone'), 1), (('gone', 'orders'), 1), (('orders', 'another'), 1), (('another', 'boat'), 1), (('boat', 'caught'), 1), (('caught', 'three'), 1), (('three', 'good'), 1), (('good', 'fish'), 1), (('first', 'week'), 1), (('week', 'made'), 1), (('made', 'boy'), 1), (('boy', 'sad'), 1), (('sad', 'see'), 1), (('see', 'old'), 1), (('man', 'come'), 1), (('come', 'day'), 1), (('day', 'skiff'), 1), (('skiff', 'empty'), 1), (('empty', 'always'), 1), (('always', 'went'), 1), (('went', 'help'), 1), (('help', 'carry'), 1), (('carry', 'either'), 1), (('either', 'coiled'), 1), (('harpoon', 'sail'), 1), (('sail', 'furled'), 1), (('furled', 'around'), 1), (('around', 'mast'), 1), (('mast', 'sail'), 1), (('sail', 'patched'), 1), (('patched', 'flour'), 1), (('flour', 'sacks'), 1), (('sacks', 'furled'), 1), (('furled', 'looked'), 1), (('looked', 'like'), 1), (('like', 'flag'), 1), (('flag', 'permanent'), 1), (('permanent', 'defeat'), 1), (('defeat', 'old'), 1), (('man', 'thin'), 1), (('thin', 'gaunt'), 1), (('gaunt', 'deep'), 1), (('deep', 'wrinkles'), 1), (('wrinkles', 'back'), 1), (('back', 'neck'), 1), (('neck', 'brown'), 1), (('brown', 'blotches'), 1), (('blotches', 'benevolent'), 1)]

# %%
#Add-1 smoothing is performed here.
            
ngrams_all = {1:[], 2:[], 3:[], 4:[]}
for i in range(3):
    for each in tokenized_text:
        for j in ngrams(each, i+1):
            ngrams_all[i+1].append(j);
ngrams_voc = {1:set([]), 2:set([]), 3:set([]), 4:set([])}
for i in range(4):
    for gram in ngrams_all[i+1]:
        if gram not in ngrams_voc[i+1]:
            ngrams_voc[i+1].add(gram)
total_ngrams = {1:-1, 2:-1, 3:-1, 4:-1}
total_voc = {1:-1, 2:-1, 3:-1, 4:-1}
for i in range(4):
    total_ngrams[i+1] = len(ngrams_all[i+1])
    total_voc[i+1] = len(ngrams_voc[i+1])                       
    
ngrams_prob = {1:[], 2:[], 3:[], 4:[]}
for i in range(4):
    for ngram in ngrams_voc[i+1]:
        tlist = [ngram]
        tlist.append(ngrams_all[i+1].count(ngram))
        ngrams_prob[i+1].append(tlist)
    
for i in range(4):
    for ngram in ngrams_prob[i+1]:
        ngram[-1] = (ngram[-1]+1)/(total_ngrams[i+1]+total_voc[i+1])

# %%
#Prints top 10 unigram, bigram, trigram, fourgram after smoothing
print("Most common n-grams without stopword removal and with add-1 smoothing: \n")
for i in range(4):
    ngrams_prob[i+1] = sorted(ngrams_prob[i+1], key = lambda x:x[1], reverse = True)
    
print ("Most common unigrams: ", str(ngrams_prob[1][:30]))
print ("\nMost common bigrams: ", str(ngrams_prob[2][:100]))
print ("\nMost common trigrams: ", str(ngrams_prob[3][:100]))
print ("\nMost common fourgrams: ", str(ngrams_prob[4][:10]))
# Out:
# Most common n-grams without stopword removal and with add-1 smoothing:
#
# Most common unigrams:  [[('the',), 0.07308781869688386], [('and',), 0.03456090651558073], [('i',), 0.017563739376770537], [('old',), 0.01586402266288952], [('to',), 0.01529745042492918], [('you',), 0.01529745042492918], [('man',), 0.014164305949008499], [('a',), 0.013031161473087818], [('was',), 0.012464589235127478], [('said',), 0.01189801699716714], [('of',), 0.0113314447592068], [('he',), 0.0113314447592068], [('in',), 0.0113314447592068], [('boy',), 0.01076487252124646], [('with',), 0.009631728045325779], [('had',), 0.009065155807365438], [('but',), 0.0084985835694051], [('were',), 0.0084985835694051], [('it',), 0.0084985835694051], [('they',), 0.0084985835694051], [('him',), 0.00793201133144476], [('his',), 0.0073654390934844195], [('can',), 0.0073654390934844195], [('fish',), 0.006798866855524079], [('that',), 0.0056657223796034], [('out',), 0.0056657223796034], [('on',), 0.0056657223796034], [('boat',), 0.0056657223796034], [('from',), 0.0056657223796034], [('are',), 0.0050991501416430595]]
#
# Most common bigrams:  [[('old', 'man'), 0.0108499095840868], [('the', 'old'), 0.010397830018083183], [('the', 'boy'), 0.007233273056057866], [('and', 'the'), 0.006781193490054249], [('man', 'said'), 0.004972875226039783], [('of', 'the'), 0.00406871609403255], [('boy', 'said'), 0.00406871609403255], [('i', 'can'), 0.0031645569620253164], [('on', 'the'), 0.0031645569620253164], [('and', 'he'), 0.0027124773960217], [('in', 'the'), 0.0027124773960217], [('he', 'was'), 0.0027124773960217], [('they', 'were'), 0.0027124773960217], [('in', 'a'), 0.0027124773960217], [('it', 'was'), 0.0022603978300180833], [('to', 'the'), 0.0022603978300180833], [('from', 'the'), 0.0018083182640144665], [('and', 'then'), 0.0018083182640144665], [('when', 'the'), 0.0018083182640144665], [('gaff', 'and'), 0.0018083182640144665], [('no', 'the'), 0.0018083182640144665], [('the', 'mast'), 0.0018083182640144665], [('he', 'had'), 0.0018083182640144665], [('it', 'is'), 0.0018083182640144665], [('take', 'the'), 0.0018083182640144665], [('the', 'sail'), 0.0018083182640144665], [('out', 'and'), 0.0018083182640144665], [('i', 'would'), 0.0018083182640144665], [('the', 'box'), 0.0018083182640144665], [('with', 'the'
009009009009009009], [('said', 'to', 'him'), 0.0009009009009009009], [('i', 'put', 'them'), 0.0009009009009009009], [('all', 'over', 'me'), 0.0009009009009009009], [('with', 'deep', 'wrinkles'), 0.0009009009009009009], [('throw', 'the', 'net'), 0.0009009009009009009], [('old', 'man', 'but'), 0.0009009009009009009], [('kills', 'the', 'eyes'), 0.0009009009009009009], [('tail', 'slapping', 'and'), 0.0009009009009009009], [('except', 'his', ' ...
#
# Most common fourgrams:  []

# %%
str1 = 'the old man said the boy'
str2 = 'man said the'

# %%
#smoothed models without stopwords removed are used
token_1 = word_tokenize(str1)
token_2 = word_tokenize(str2)
ngram_1 = {1:[], 2:[], 3:[]}   #to store the n-grams formed  
ngram_2 = {1:[], 2:[], 3:[]}
for i in range(3):
    ngram_1[i+1] = list(ngrams(token_1, i+1))[-1]
    ngram_2[i+1] = list(ngrams(token_2, i+1))[-1]
print("String 1: ", ngram_1,"\nString 2: ",ngram_2)
# Out:
# String 1:  {1: ('boy',), 2: ('the', 'boy'), 3: ('said', 'the', 'boy')}
# String 2:  {1: ('the',), 2: ('said', 'the'), 3: ('man', 'said', 'the')}

# %%
for i in range(3):
    ngrams_prob[i+1] = sorted(ngrams_prob[i+1], key = lambda x:x[1], reverse = True)
    
pred_1 = {1:[], 2:[], 3:[]}
for i in range(3):
    count = 0
    for each in ngrams_prob[i+2]:
        if each[0][:-1] == ngram_1[i+1]:      
#to find predictions based on highest probability of n-grams  
                 
            count +=1
            pred_1[i+1].append(each[0][-1])
            if count ==5:
                break
    if count<5:
        while(count!=5):
            pred_1[i+1].append("NOT FOUND")           
#if no word prediction is found, replace with NOT FOUND
            count +=1
for i in range(4):
    ngrams_prob[i+1] = sorted(ngrams_prob[i+1], key = lambda x:x[1], reverse = True)
    
pred_2 = {1:[], 2:[], 3:[]}
for i in range(3):
    count = 0
    for each in ngrams_prob[i+2]:
        if each[0][:-1] == ngram_2[i+1]:
            count +=1
            pred_2[i+1].append(each[0][-1])
            if count ==5:
                break
    if count<5:
        while(count!=5):
            pred_2[i+1].append("\0")
            count +=1

# %%
print("Next word predictions for the strings using the probability models of bigrams, trigrams, and fourgrams\n")
print("String 1 - the old man said the boy-\n")
print("Bigram model predictions: {}\nTrigram model predictions: {}\nFourgram model predictions: {}\n" .format(pred_1[1], pred_1[2], pred_1[3]))
print("String 2 - You are already a-\n")
print("Bigram model predictions: {}\nTrigram model predictions: {}\nFourgram model predictions: {}" .format(pred_2[1], pred_2[2], pred_2[3]))
# Out:
# Next word predictions for the strings using the probability models of bigrams, trigrams, and fourgrams
#
# String 1 - the old man said the boy-
#
# Bigram model predictions: ['said', 'had', 'carried', 'id', 'sad']
# Trigram model predictions: ['said', 'to', 'asked', 'sad', 'carried']
# Fourgram model predictions: ['NOT FOUND', 'NOT FOUND', 'NOT FOUND', 'NOT FOUND', 'NOT FOUND']
#
# String 2 - You are already a-
#
# Bigram model predictions: ['old', 'boy', 'mast', 'sail', 'box']
# Trigram model predictions: ['\x00', '\x00', '\x00', '\x00', '\x00']
# Fourgram model predictions: ['\x00', '\x00', '\x00', '\x00', '\x00']
